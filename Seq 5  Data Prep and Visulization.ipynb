# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_pickle("End_Data.pickle")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1940934 entries, 0 to 1940933
# Data columns (total 21 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   park_id                 object
#  1   clc_code                object
#  2   area_code               object
#  3   evse_id                 object
#  4   datetime_start          datetime64[ns]
#  5   datetime_stop           datetime64[ns]
#  6   Charging_Started        category
#  7   Charging_Stop           category
#  8   city                    object
#  9   latitude                float64
#  10  longitude               float64
#  11  postal_code             category
#  12  Charging_Time_in_hours  float64
#  13  year                    category
#  14  month                   category
#  15  day                     category
#  16  day_of_week_name_Start  object
#  17  Precipitation           float64
#  18  Temperature             float64
#  19  pd                      float64
# ...

# %%
df
# Out:
#                                          park_id  clc_code     area_code  \
# 0        hj_31c455b8-420e-46af-bce6-436b65ccc416  Suburban  120650165165
# 1        hj_31c455b8-420e-46af-bce6-436b65ccc416  Suburban  120650165165
# 2        hj_31c455b8-420e-46af-bce6-436b65ccc416  Suburban  120650165165
# 3        hj_31c455b8-420e-46af-bce6-436b65ccc416  Suburban  120650165165
# 4        hj_31c455b8-420e-46af-bce6-436b65ccc416  Suburban  120650165165
# ...                                          ...       ...           ...
# 1940929                              sl_23897386     Urban  051120000000
# 1940930                              sl_23897386     Urban  051120000000
# 1940931                              sl_23897386     Urban  051120000000
# 1940932                              sl_23897386     Urban  051120000000
# 1940933                              sl_23897386     Urban  051120000000
#
#                        evse_id          datetime_start  \
# ...

# %%
df['Charging_time_in_hours_log'] = np.log(df['Charging_Time_in_hours'])
# Out:
# /home/col-gku/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df = (df
[df["Precipitation"]>=0] 
[df["Precipitation"]<=10]
)
# Out:
# <ipython-input-6-df95644cdc3d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = (df

# %%
df = (df
[df["Temperature"]>=-20]
[df["Temperature"]<=35]
)
# Out:
# <ipython-input-7-315f4e7f722a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = (df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1923923 entries, 0 to 1940933
# Data columns (total 22 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   park_id                     object
#  1   clc_code                    object
#  2   area_code                   object
#  3   evse_id                     object
#  4   datetime_start              datetime64[ns]
#  5   datetime_stop               datetime64[ns]
#  6   Charging_Started            category
#  7   Charging_Stop               category
#  8   city                        object
#  9   latitude                    float64
#  10  longitude                   float64
#  11  postal_code                 category
#  12  Charging_Time_in_hours      float64
#  13  year                        category
#  14  month                       category
#  15  day                         category
#  16  day_of_week_name_Start      object
#  17  Precipitation               float64
# ...

# %%
df
# Out:
#                                          park_id  clc_code     area_code  \
# 0        hj_31c455b8-420e-46af-bce6-436b65ccc416  Suburban  120650165165
# 1        hj_31c455b8-420e-46af-bce6-436b65ccc416  Suburban  120650165165
# 2        hj_31c455b8-420e-46af-bce6-436b65ccc416  Suburban  120650165165
# 3        hj_31c455b8-420e-46af-bce6-436b65ccc416  Suburban  120650165165
# 4        hj_31c455b8-420e-46af-bce6-436b65ccc416  Suburban  120650165165
# ...                                          ...       ...           ...
# 1940929                              sl_23897386     Urban  051120000000
# 1940930                              sl_23897386     Urban  051120000000
# 1940931                              sl_23897386     Urban  051120000000
# 1940932                              sl_23897386     Urban  051120000000
# 1940933                              sl_23897386     Urban  051120000000
#
#                        evse_id          datetime_start  \
# ...

# %%
df.to_pickle("Endresult_v1.pickle")

# %%
df.to_csv("Endresult_v1.csv")
