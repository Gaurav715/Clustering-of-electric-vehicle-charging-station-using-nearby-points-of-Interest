# %%
dw = pd.read_csv("wethear.csv")

# %%
dw
# Out:
#      Stations_id   von_datum   bis_datum  Stationshoehe  geoBreite  geoLaenge  \
# 0              3  1950-04-01  2011-03-31            202    50.7827     6.0941
# 1             44  2007-04-01  2021-08-26             44    52.9336     8.2370
# 2             52  1976-01-01  1988-01-01             46    53.6623    10.1990
# 3             71  2009-12-01  2019-12-31            759    48.2156     8.9784
# 4             73  2007-04-01  2021-08-26            340    48.6159    13.0506
# ..           ...         ...         ...            ...        ...        ...
# 640        15207  2013-11-01  2021-08-26            317    51.2835     9.3590
# 641        15444  2014-09-01  2021-08-26            593    48.4418     9.9216
# 642        15555  2016-05-01  2021-08-26            815    47.8761    10.5849
# 643        19171  2020-09-01  2021-08-26             13    54.0038     9.8553
# 644        19172  2020-09-01  2021-08-26             48    54.0246     9.3880
#
# ...

# %%
dw=dw.rename(columns = {'von_datum':'from_date','bis_datum':'till date','Stationshoehe':'station height'
                     ,'geoBreite':'geoLatitude','geoLaenge':'geoLongitude','Bundesland':'federal state'})

# %%
dw
# Out:
#      Stations_id   from_date   till date  station height  geoLatitude  \
# 0              3  1950-04-01  2011-03-31             202      50.7827
# 1             44  2007-04-01  2021-08-26              44      52.9336
# 2             52  1976-01-01  1988-01-01              46      53.6623
# 3             71  2009-12-01  2019-12-31             759      48.2156
# 4             73  2007-04-01  2021-08-26             340      48.6159
# ..           ...         ...         ...             ...          ...
# 640        15207  2013-11-01  2021-08-26             317      51.2835
# 641        15444  2014-09-01  2021-08-26             593      48.4418
# 642        15555  2016-05-01  2021-08-26             815      47.8761
# 643        19171  2020-09-01  2021-08-26              13      54.0038
# 644        19172  2020-09-01  2021-08-26              48      54.0246
#
#      geoLongitude                  Stationsname           federal state
# ...

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(dw, title="Pandas Profiling Report")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-01-21 15:08:22.235981&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
